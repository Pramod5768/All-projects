# %% [markdown]
# # Market Segmentation
#
# In marketing, market segmentation is the process of
# dividing a broad consumer or business market, normally
# consisting of existing and potential customers, into subgroups of consumers based on some type of shared
# characteristics.
#
# ****
# # Objective
# A case requires to develop a customer segmentation to
# give recommendations like saving plans, loans, wealth
# management, etc. on target customers groups.
# ****
# # Dataset
# The sample Dataset summarizes the usage behavior of about 9000 active credit card
# holders during the last 6 months. The file is at a customer level with 18 behavioral
# variables.

# %% [markdown]
# # IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
scalar=StandardScaler()
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans,AgglomerativeClustering,DBSCAN,SpectralClustering
from sklearn.mixture import GaussianMixture
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn import tree
from sklearn import metrics

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("Customer Data.csv")
df
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.shape
# Out:
# (8950, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
df.isnull()
# Out:
#       CUST_ID  BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       False    False              False      False             False
# 1       False    False              False      False             False
# 2       False    False              False      False             False
# 3       False    False              False      False             False
# 4       False    False              False      False             False
# ...       ...      ...                ...        ...               ...
# 8945    False    False              False      False             False
# 8946    False    False              False      False             False
# 8947    False    False              False      False             False
# 8948    False    False              False      False             False
# 8949    False    False              False      False             False
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
df.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
df.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
df["MINIMUM_PAYMENTS"]=df["MINIMUM_PAYMENTS"].fillna(df["MINIMUM_PAYMENTS"].mean())
df["CREDIT_LIMIT"]=df["CREDIT_LIMIT"].fillna(df["CREDIT_LIMIT"].mean())

# %%
# drop CUST_ID column because it is not used
df.drop(columns=["CUST_ID"],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES', 'ONEOFF_PURCHASES',
#        'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE', 'PURCHASES_FREQUENCY',
#        'ONEOFF_PURCHASES_FREQUENCY', 'PURCHASES_INSTALLMENTS_FREQUENCY',
#        'CASH_ADVANCE_FREQUENCY', 'CASH_ADVANCE_TRX', 'PURCHASES_TRX',
#        'CREDIT_LIMIT', 'PAYMENTS', 'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT',
#        'TENURE'],
#       dtype='object')

# %%
#plotting kde curve to see the distribution of the data
plt.figure(figsize=(30,45))
for i, col in enumerate(df.columns):
    if df[col].dtype != 'object':
        ax = plt.subplot(9, 2, i+1)
        sns.kdeplot(df[col], ax=ax)
        plt.xlabel(col)
        
plt.show()

# %%
plt.figure(figsize=(10,60))
for i in range(0,17):
    plt.subplot(17,1,i+1)
    sns.distplot(df[df.columns[i]],kde_kws={'color':'b','bw': 0.1,'lw':3,'label':'KDE'},hist_kws={'color':'g'})
    plt.title(df.columns[i])
plt.tight_layout()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %% [markdown]
# # SCALING THE DATA

# %%
scalar=StandardScaler()
scaled_df=scalar.fit_transform(df)
scaled_df
# Out:
# array([[-0.73198937, -0.24943448, -0.42489974, ..., -0.31096755,
#         -0.52555097,  0.36067954],
#        [ 0.78696085,  0.13432467, -0.46955188, ...,  0.08931021,
#          0.2342269 ,  0.36067954],
#        [ 0.44713513,  0.51808382, -0.10766823, ..., -0.10166318,
#         -0.52555097,  0.36067954],
#        ...,
#        [-0.7403981 , -0.18547673, -0.40196519, ..., -0.33546549,
#          0.32919999, -4.12276757],
#        [-0.74517423, -0.18547673, -0.46955188, ..., -0.34690648,
#          0.32919999, -4.12276757],
#        [-0.57257511, -0.88903307,  0.04214581, ..., -0.33294642,
#         -0.52555097, -4.12276757]])

# %% [markdown]
# # Dimensionality Reduction
# **Converting the dataframe into 2 dimension for visualization and feature extracting to avoid overfitting of the data**

# %%
pca = PCA(n_components=2)
principal_components = pca.fit_transform(scaled_df)
pca_df = pd.DataFrame(data=principal_components ,columns=["PCA1","PCA2"])
pca_df
# Out:
#           PCA1      PCA2
# 0    -1.682220 -1.076454
# 1    -1.138290  2.506430
# 2     0.969688 -0.383536
# 3    -0.873628  0.043159
# 4    -1.599434 -0.688579
# ...        ...       ...
# 8945 -0.359631 -2.016131
# 8946 -0.564374 -1.639097
# 8947 -0.926206 -1.810770
# 8948 -2.336556 -0.657940
# 8949 -0.556422 -0.400461
#
# [8950 rows x 2 columns]

# %%
print(pca.explained_variance_ratio_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-63e90d88b823> in <cell line: 1>()
# ----> 1 print(pca.explained_variance_ratio_)
#
# NameError: name 'pca' is not defined

# %% [markdown]
# # Hyperparameter tuning
# ## Finding 'k' value by Elbow Method

# %%
inertia = []
range_val = range(1,15)
for i in range_val:
    kmean = KMeans(n_clusters=i)
    kmean.fit_predict(pd.DataFrame(pca_df))
    inertia.append(kmean.inertia_)
plt.plot(range_val,inertia,'bx-')
plt.xlabel('Values of K') 
plt.ylabel('Inertia') 
plt.title('The Elbow Method using Inertia') 
plt.show()

# %%
from sklearn.cluster import DBSCAN

# Apply DBSCAN clustering
dbscan = DBSCAN(eps=1.8, min_samples=5)
db_clusters = dbscan.fit_predict(pca_df)

# Print the cluster labels assigned by DBSCAN
print("Cluster labels:", db_clusters)

n_clusters = len(np.unique(db_clusters))

# Print the cluster labels assigned by DBSCAN and the total number of clusters
print("Cluster labels:", db_clusters)
print("Total number of clusters:", n_clusters)
# Out:
# Cluster labels: [0 0 0 ... 0 0 0]
# Cluster labels: [0 0 0 ... 0 0 0]
# Total number of clusters: 3

# %%
sns.scatterplot(x="PCA1",y="PCA2",hue=db_clusters,data=pca_df,palette='viridis')
# Out:
# <Axes: xlabel='PCA1', ylabel='PCA2'>

# %%
dbscan_score = silhouette_score(pca_df, db_clusters)
print(f"Silhouette score for DBSCAN: {dbscan_score}")
# Out:
# Silhouette score for DBSCAN: 0.8027988906480655

# %%
import scipy.cluster.hierarchy as shc

plt.figure(figsize=(10, 7))
plt.title("Customer Dendograms")
dend = shc.dendrogram(shc.linkage(pca_df, method='ward'))

# %%
from sklearn.cluster import AgglomerativeClustering

cluster = AgglomerativeClustering(n_clusters=5, affinity='euclidean', linkage='ward')
labels_agg=cluster.fit_predict(pca_df)
labels_agg
# Out:
# array([2, 0, 4, ..., 4, 2, 2])

# %%
sns.scatterplot(x="PCA1",y="PCA2",hue=labels_agg,data=pca_df,palette='rainbow')
# Out:
# <Axes: xlabel='PCA1', ylabel='PCA2'>

# %%
agg_score = silhouette_score(pca_df, labels_agg)
print(f"Silhouette score for Heirarchical clustering: {agg_score}")
# Out:
# Silhouette score for Heirarchical clustering: 0.34407546549968704

# %% [markdown]
# # Model Building using KMeans

# %%
kmeans_model=KMeans(4)
kmeans_model.fit_predict(scaled_df)
pca_df_kmeans= pd.concat([pca_df,pd.DataFrame({'cluster':kmeans_model.labels_})],axis=1)
pca_df_kmeans
# Out:
#           PCA1      PCA2  cluster
# 0    -1.682220 -1.076454        0
# 1    -1.138290  2.506430        2
# 2     0.969688 -0.383536        1
# 3    -0.873628  0.043159        0
# 4    -1.599434 -0.688579        0
# ...        ...       ...      ...
# 8945 -0.359631 -2.016131        1
# 8946 -0.564374 -1.639097        1
# 8947 -0.926206 -1.810770        1
# 8948 -2.336556 -0.657940        0
# 8949 -0.556422 -0.400461        0
#
# [8950 rows x 3 columns]

# %% [markdown]
# # Visualizing the clustered dataframe

# %%
plt.figure(figsize=(8,8))
ax=sns.scatterplot(x="PCA1",y="PCA2",hue="cluster",data=pca_df_kmeans,palette=['red','green','blue','black'])
plt.title("Clustering using K-Means Algorithm")
plt.show()

# %%
kmeans_score = silhouette_score(scaled_df, kmeans_model.labels_)
print(f"Silhouette score for K-means: {kmeans_score}")
# Out:
# Silhouette score for K-means: 0.1972452264593208

# %%
# find all cluster centers
cluster_centers = pd.DataFrame(data=kmeans_model.cluster_centers_,columns=[df.columns])
cluster_centers = scalar.inverse_transform(cluster_centers)
cluster_centers = pd.DataFrame(data=cluster_centers,columns=[df.columns])
cluster_centers
# inverse transform the data
#because we need to attach the clusters to original dataframe
# Out:
#        BALANCE BALANCE_FREQUENCY    PURCHASES ONEOFF_PURCHASES  \
# 0  1004.675596          0.789148   270.156816       209.778663
# 1   895.426332          0.934912  1236.730523       594.327905
# 2  4581.655892          0.968438   493.151346       313.745458
# 3  3556.148177          0.986911  7680.432073      5099.738293
#
#   INSTALLMENTS_PURCHASES CASH_ADVANCE PURCHASES_FREQUENCY  \
# 0              60.645984   590.016884            0.170718
# 1             642.676996   210.695779            0.885369
# 2             179.489843  4485.168482            0.284523
# 3            2582.157195   686.680975            0.946548
#
#   ONEOFF_PURCHASES_FREQUENCY PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                   0.086435                         0.080942
# 1                   0.297247                         0.711943
# 2                   0.136967                         0.183199
# 3                   0.739667                         0.788577
#
# ...

# %%
# Creating a target column "Cluster" for storing the cluster segment
cluster_df = pd.concat([df,pd.DataFrame({'Cluster':kmeans_model.labels_})],axis=1)
cluster_df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
cluster_1_df = cluster_df[cluster_df["Cluster"]==0]
cluster_1_df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# 8     1014.926473           1.000000     861.49            661.49
# 9      152.225975           0.545455    1281.60           1281.60
# ...           ...                ...        ...               ...
# 8939   728.352548           1.000000     734.40            734.40
# 8943     5.871712           0.500000      20.90             20.90
# 8944   193.571722           0.833333    1012.73           1012.73
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                       95.4      0.000000             0.166667
# ...

# %%
cluster_2_df = cluster_df[cluster_df["Cluster"]==1]
cluster_2_df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 2     2495.148862           1.000000     773.17            773.17
# 5     1809.828751           1.000000    1333.28              0.00
# 7     1823.652743           1.000000     436.20              0.00
# 10    1293.124939           1.000000     920.12              0.00
# 12    1516.928620           1.000000    3217.99           2500.23
# ...           ...                ...        ...               ...
# 8940   130.838554           1.000000     591.24              0.00
# 8942    40.829749           1.000000     113.28              0.00
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 2                       0.00           0.0             1.000000
# ...

# %%
cluster_3_df = cluster_df[cluster_df["Cluster"]==2]
cluster_3_df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 1     3202.467416           0.909091       0.00              0.00
# 15    6886.213231           1.000000    1611.70              0.00
# 23    3800.151377           0.818182    4248.35           3454.56
# 24    5368.571219           1.000000       0.00              0.00
# 28    7152.864372           1.000000     387.05            204.55
# ...           ...                ...        ...               ...
# 8857  2330.222764           1.000000    1320.00              0.00
# 8858   812.934042           1.000000      50.00             50.00
# 8869  2171.222526           1.000000     791.18            791.18
# 8915   381.341657           1.000000      78.00              0.00
# 8941  5967.475270           0.833333     214.55              0.00
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 1                       0.00   6442.945483             0.000000
# ...

# %%
cluster_4_df = cluster_df[cluster_df["Cluster"] == 3]
cluster_4_df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 6      627.260806           1.000000    7091.01           6402.63
# 21    6369.531318           1.000000    6359.95           5910.04
# 57    2386.330629           1.000000    5217.62           4789.09
# 84    1935.362486           1.000000    4915.60           4515.34
# 90    9381.255094           1.000000    5100.07           1147.83
# ...           ...                ...        ...               ...
# 8215  4436.557694           1.000000    6005.90           5838.38
# 8541  3326.323283           1.000000    8209.77           2218.28
# 8662   599.909949           1.000000    4947.32           3149.59
# 8689   368.318662           0.909091    8053.95           8053.95
# 8737  2533.618119           0.909091    5633.83           2985.92
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 6                     688.38      0.000000             1.000000
# ...

# %%
#Visualization
sns.countplot(x='Cluster', data=cluster_df)
# Out:
# <Axes: xlabel='Cluster', ylabel='count'>

# %%
for c in cluster_df.drop(['Cluster'],axis=1):
    grid= sns.FacetGrid(cluster_df, col='Cluster')
    grid= grid.map(plt.hist, c)
plt.show()

# %% [markdown]
# # Saving the kmeans clustering model and the data with cluster label

# %%
#Saving Scikitlearn models
import joblib
joblib.dump(kmeans_model, "kmeans_model.pkl")
# Out:
# ['kmeans_model.pkl']

# %%
cluster_df.to_csv("Clustered_Customer_Data.csv")

# %% [markdown]
# # Training and Testing the model accuracy using decision tree

# %%
#Split Dataset
X = cluster_df.drop(['Cluster'],axis=1)
y= cluster_df[['Cluster']]
X_train, X_test, y_train, y_test =train_test_split(X, y, test_size=0.3)

# %%
X_train
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 8655   154.416929           1.000000     483.27            483.27
# 736      0.255710           0.090909      24.00              0.00
# 2391  2416.771489           1.000000    4201.13           3802.21
# 2086  3386.490883           1.000000     560.98            427.22
# 506   1529.206464           1.000000     874.94              0.00
# ...           ...                ...        ...               ...
# 6177    77.087831           0.363636     311.81            311.81
# 6454    12.478094           0.500000     217.91              0.00
# 2416  1902.665938           1.000000    4666.51           4464.76
# 5757    48.660932           1.000000     651.08            100.00
# 926    179.290727           1.000000    2540.90           1234.77
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 8655                    0.00    108.462594             0.416667
# ...

# %%
X_test
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 8498    39.885648           1.000000     433.32              0.00
# 6755   497.510544           1.000000     569.94            141.40
# 6741   177.551278           0.636364      66.25              0.00
# 4051    70.963378           1.000000     759.73            432.37
# 1964    51.427334           1.000000     486.01            486.01
# ...           ...                ...        ...               ...
# 1187  2191.369256           1.000000    1197.20            869.06
# 369   6388.108487           1.000000       0.00              0.00
# 6986  4761.191310           0.833333    4085.81           3157.31
# 3318    79.462211           0.727273    1073.97           1073.97
# 619   3774.063585           1.000000    7680.08           5050.97
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 8498                  433.32      0.000000             1.000000
# ...

# %%
#Decision_Tree
model= DecisionTreeClassifier(criterion="entropy")
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
#Confusion_Matrix
print(metrics.confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[1132   33   25    0]
#  [  37  951   11    7]
#  [  29   18  307    2]
#  [   1   15    0  117]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.95      0.95      1190
#            1       0.94      0.95      0.94      1006
#            2       0.90      0.86      0.88       356
#            3       0.93      0.88      0.90       133
#
#     accuracy                           0.93      2685
#    macro avg       0.93      0.91      0.92      2685
# weighted avg       0.93      0.93      0.93      2685

# %% [markdown]
# # Saving the Decision tree model for future prediction

# %%
import pickle
filename = 'final_model.sav'
pickle.dump(model, open(filename, 'wb'))
 
# some time later...
 
# load the model from disk
loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.score(X_test, y_test)
print(result,'% Acuuracy')
# Out:
# 0.933705772811918 % Acuuracy
